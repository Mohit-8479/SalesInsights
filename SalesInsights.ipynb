# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

# Display the first few rows of the DataFrame to understand the data structure
print(df.head())

item_sales = df.groupby("Item")["Sale_amt"].sum().sort_values(ascending=False)
print("\nTotal Sales by Item:")
print(item_sales)

# Visualize the Total Sales by Item
plt.figure(figsize=(10, 6))
item_sales.plot(kind="bar")
plt.title("Total Sales by Item")
plt.xlabel("Item")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0
#
# Total Sales by Item:
# Item
# Television      857768.0
# Home Theater    361000.0
# Cell Phone       62550.0
# Video Games      23107.5
# Desk              1250.0
# Name: Sale_amt, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

# Display the first few rows of the DataFrame to understand the data structure
print(df.head())

# Convert OrderDate to datetime format
df['OrderDate'] = pd.to_datetime(df['OrderDate'], format='%m-%d-%y')

# Extract the month from the OrderDate and create a new column 'Month'
df['Month'] = df['OrderDate'].dt.to_period('M')

# Group by Month and calculate total sales for each month
monthly_sales = df.groupby('Month')['Sale_amt'].sum()

# Convert the 'Month' index to strings
monthly_sales.index = monthly_sales.index.strftime('%Y-%m')

print("Total Sales by Month")
print(monthly_sales.index)
print(monthly_sales.values)
# Visualize the Monthly Sales Trend
plt.figure(figsize=(10, 6))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o', linestyle='-')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0
# Total Sales by Month
# Index(['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#        '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'],
#       dtype='object', name='Month')
# [138810.   49203.   67088.  119850.  146156.  137820.   55000.   41930.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

manager_sales = df.groupby('Manager')['Sale_amt'].sum().sort_values(ascending=False)

# Display the top 5 managers by sales
top_managers = manager_sales.head(5)
print("Top 5 Managers by Sales:")
print(top_managers)
# Out:
# Top 5 Managers by Sales:
# Manager
# Martha     472493.0
# Hermann    365108.5
# Douglas    239056.0
# Timothy    229018.0
# Name: Sale_amt, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

manager_sales = df.groupby('Manager')['Sale_amt'].sum().sort_values(ascending=False)

# Display the top 5 managers by sales
top_managers = manager_sales.head(5)
print("Top 5 Managers by Sales:")
print(top_managers)

import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

# Group by 'Region' and calculate total sales for each region
region_distribution = df.groupby('Region')['Sale_amt'].sum()

# Display the distribution of sales by payment method
print("Sales Distribution by Region:")
print(region_distribution)
# Out:
# Top 5 Managers by Sales:
# Manager
# Martha     472493.0
# Hermann    365108.5
# Douglas    239056.0
# Timothy    229018.0
# Name: Sale_amt, dtype: float64
# Sales Distribution by Region:
# Region
# Central    829769.5
# East       321007.0
# West       154899.0
# Name: Sale_amt, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

saleman_sales = df.groupby('SalesMan')['Sale_amt'].sum().sort_values(ascending=False)

# Display the sales done by each sales man
print(saleman_sales)
# Out:
# SalesMan
# Alexander    236703.0
# Luis         206373.0
# Steven       199690.0
# David        140955.0
# Sigal        125037.5
# John         124016.0
# Stephen       88063.0
# Michael       66836.0
# Karen         48204.0
# Diana         36100.0
# Shelli        33698.0
# Name: Sale_amt, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

saleman_sales = df.groupby('SalesMan')['Sale_amt'].sum().sort_values(ascending=False)

# Display the sales done by each sales man
print(saleman_sales)

import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel('SaleData.xlsx')
# print(file["Item"])

sales_manager_sales = df.groupby('SalesMan')['Sale_amt'].sum().sort_values(ascending=False)

# Display the top 5 Sales Man by sales
top_salesman = sales_manager_sales.head(5)
print("Top 5 Sales Man by Sales:")
print(top_salesman)
# Out:
# SalesMan
# Alexander    236703.0
# Luis         206373.0
# Steven       199690.0
# David        140955.0
# Sigal        125037.5
# John         124016.0
# Stephen       88063.0
# Michael       66836.0
# Karen         48204.0
# Diana         36100.0
# Shelli        33698.0
# Name: Sale_amt, dtype: float64
# Top 5 Sales Man by Sales:
# SalesMan
# Alexander    236703.0
# Luis         206373.0
# Steven       199690.0
# David        140955.0
# Sigal        125037.5
# Name: Sale_amt, dtype: float64
